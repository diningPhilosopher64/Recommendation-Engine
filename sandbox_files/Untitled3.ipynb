# %%
import imdb
from BeautifulSoup import BeautifulSoup
import urllib2 
import os
import requests
import bs4
import numpy as np
import pandas as pd
from threading import Thread
import json,requests,unicodedata,urllib2
import time


# set some print options
np.set_printoptions(precision=4)
np.set_printoptions(threshold=5)
np.set_printoptions(suppress=True)
pd.set_option('precision', 3, 'notebook_repr_html', True, )

# init random gen
np.random.seed(2)



movies_file = "/media/sourabhkondapaka/Sourabh's/main_project/sandbox/ml-latest-small/movies.csv"
movies = pd.read_table(movies_file, sep=',')
movies.columns = ['movie_id','title','genres']
names = movies['title']

ia = imdb.IMDb()

file_path = "/media/sourabhkondapaka/Sourabh's/main_project/sandbox/images2/"

threadlist = []

file_path2 = "/media/sourabhkondapaka/Sourabh's/main_project/sandbox/images2"
def th():
    global counter    
    bb = str(movies.ix[movies['movie_id'] == counter ]['title']).split()    
    q = bb.index('Name:')
    bb = ' '.join(bb[1:q]) 
    print("Counter value for movie " + bb + str(counter))
    try:
        print("Downloading the image :" + bb)
        item = ia.search_movie(bb)[0]
        print("Name in item is " + str(item))
        name = str(item)        
        ll = name.split()
        #ll = '+'.join(ll)
        movie_url = url + '+'.join(ll)
        print movie_url
        content = urllib2.urlopen(movie_url).read()
        jsontopython = json.loads(content)
        img = requests.get(jsontopython['Poster'])
        imgfile = open(file_path2+"/"+bb,'wb')
        for chunk in img.iter_content(100000):
            imgfile.write(chunk)
        imgfile.close()
        
    except IndexError:
        global missing_movies
        missing_movies.append(bb)
        print("counter value :"+str(counter))
        print("Error with " + bb)




missing_movies=[]

url = "http://www.omdbapi.com/?t="

file = open("counter.txt","r")
counter = int(file.read())


def thread_creator():    
    global threadlist
    global counter
    print("Counter value before starting threads is : " + str(counter))
    for u in range(1000):
        t = Thread(target = th ,args=())
        
        t.start() 
        time.sleep(1)
        counter = counter + 1
        threadlist.append(t)
        #time.sleep(2)
              
        #global threadlist
        

def thread_joiner():
    global threadlist
    global counter
    for b in threadlist:
        b.join()
    with open("counter.txt", "w") as text_file:
        text_file.write("{} ".format(counter))

# %%
thread_creator()
thread_joiner()
# Out:
# Counter value before starting threads is : 0
# Counter value for movie 0
# Downloading the image :
# counter value :0
# Error with
# Counter value for movie Toy Story (1995)1
# Downloading the image :Toy Story (1995)
# Name in item is Toy Story
# http://www.omdbapi.com/?t=Toy+Story
# Counter value for movie Jumanji (1995)2
# Downloading the image :Jumanji (1995)
# Name in item is Jumanji
# http://www.omdbapi.com/?t=Jumanji
# Counter value for movie Grumpier Old Men (1995)3
# Downloading the image :Grumpier Old Men (1995)
# Name in item is Grumpier Old Men
# http://www.omdbapi.com/?t=Grumpier+Old+Men
# Counter value for movie Waiting to Exhale (1995)4
# Downloading the image :Waiting to Exhale (1995)
# Counter value for movie Father of the Bride Part II (1995)5
# Downloading the image :Father of the Bride Part II (1995)
# Name in item is Waiting to Exhale
# http://www.omdbapi.com/?t=Waiting+to+Exhale
# Name in item is Father of the Bride Part II
# http://www.omdbapi.com/?t=Father+of+the+Bride+Part+II
# Downloading the image :Othello (1995)
# Name in item is Leaving Las Vegas
# http://www.omdbapi.com/?t=Leaving+Las+Vegas
# Name in item is Othello
# http://www.omdbapi.com/?t=Othello
# Counter value for movie Now and Then (1995)27
# Downloading the image :Now and Then (1995)
# Counter value for movie Persuasion (1995)28
# Downloading the image :Persuasion (1995)
# Name in item is Now and Then
# http://www.omdbapi.com/?t=Now+and+Then
# Counter value for movie City of Lost Children, The (Cité des enfants p...29
# Downloading the image :City of Lost Children, The (Cité des enfants p...
# Name in item is Persuasion (1995) (TV Episode)  - Season 11 | Episode 3  - Screen Two
# http://www.omdbapi.com/?t=Persuasion+(1995)+(TV+Episode)+-+Season+11+|+Episode+3+-+Screen+Two
# counter value :29
# Error with City of Lost Children, The (Cité des enfants p...
# Counter value for movie Shanghai Triad (Yao a yao yao dao waipo qiao) ...30
# Downloading the image :Shanghai Triad (Yao a yao yao dao waipo qiao) ...
# Exception in thread Thread-52:
# Traceback (most recent call last):
#   File "/home/sourabhkondapaka/anaconda3/envs/py2/lib/python2.7/threading.py", line 801, in __bootstrap_inner
#     self.run()
#   File "/home/sourabhkondapaka/anaconda3/envs/py2/lib/python2.7/threading.py", line 754, in run
#     self.__target(*self.__args, **self.__kwargs)
#   File "<ipython-input-4-a7de096a7c9f>", line 54, in th
#     img = requests.get(jsontopython['Poster'])
# KeyError: 'Poster'
# counter value :30
# Error with Shanghai Triad (Yao a yao yao dao waipo qiao) ...
# Counter value for movie Dangerous Minds (1995)31
# Downloading the image :Dangerous Minds (1995)
# Name in item is Dangerous Minds
# http://www.omdbapi.com/?t=Dangerous+Minds
# Counter value for movie Twelve Monkeys (a.k.a. 12 Monkeys) (1995)32
# Downloading the image :Twelve Monkeys (a.k.a. 12 Monkeys) (1995)
# counter value :32
# Error with Twelve Monkeys (a.k.a. 12 Monkeys) (1995)
# Counter value for movie 33
# Downloading the image :
# Counter value for movie Babe (1995)34
# Downloading the image :Babe (1995)
# counter value :34
# Error with
# Name in item is Babe
# http://www.omdbapi.com/?t=Babe
# Counter value for movie Carrington (1995)35
# Downloading the image :Carrington (1995)
# Name in item is Carrington
# http://www.omdbapi.com/?t=Carrington
# Counter value for movie Dead Man Walking (1995)36
# Downloading the image :Dead Man Walking (1995)
# Counter value for movie Across the Sea of Time (1995)37
# Downloading the image :Across the Sea of Time (1995)
# Name in item is Dead Man Walking
# http://www.omdbapi.com/?t=Dead+Man+Walking
# Name in item is Across the Sea of Time
# http://www.omdbapi.com/?t=Across+the+Sea+of+Time
# Counter value for movie It Takes Two (1995)38
# Downloading the image :It Takes Two (1995)
# Name in item is It Takes Two
# http://www.omdbapi.com/?t=It+Takes+Two
# Counter value for movie Clueless (1995)39
# Downloading the image :Clueless (1995)
# Counter value for movie Cry, the Beloved Country (1995)40
# Downloading the image :Cry, the Beloved Country (1995)
# Name in item is Clueless
# http://www.omdbapi.com/?t=Clueless
# Counter value for movie Richard III (1995)41
# Downloading the image :Richard III (1995)
# Name in item is Cry, the Beloved Country
# http://www.omdbapi.com/?t=Cry,+the+Beloved+Country
# Counter value for movie Dead Presidents (1995)42
# Downloading the image :Dead Presidents (1995)
# Name in item is Richard III
# http://www.omdbapi.com/?t=Richard+III
# Name in item is Dead Presidents
# http://www.omdbapi.com/?t=Dead+Presidents
# Counter value for movie Restoration (1995)43
# Downloading the image :Restoration (1995)
# Counter value for movie Mortal Kombat (1995)44
# Downloading the image :Mortal Kombat (1995)
# Name in item is Restoration
# http://www.omdbapi.com/?t=Restoration
# Counter value for movie To Die For (1995)45
# Downloading the image :To Die For (1995)
# Name in item is Mortal Kombat
# Counter value for movie Antonia's Line (Antonia) (1995)82
# Downloading the image :Antonia's Line (Antonia) (1995)
# Name in item is Antonia's Line
# http://www.omdbapi.com/?t=Antonia's+Line
# Counter value for movie Once Upon a Time... When We Were Colored (1995)83
# Downloading the image :Once Upon a Time... When We Were Colored (1995)
# Name in item is Once Upon a Time... When We Were Colored
# http://www.omdbapi.com/?t=Once+Upon+a+Time...+When+We+Were+Colored
# Counter value for movie Last Summer in the Hamptons (1995)84
# Downloading the image :Last Summer in the Hamptons (1995)
# Counter value for movie Angels and Insects (1995)85
# Downloading the image :Angels and Insects (1995)
# Name in item is Last Summer in the Hamptons
# http://www.omdbapi.com/?t=Last+Summer+in+the+Hamptons
# Name in item is Angels and Insects
# http://www.omdbapi.com/?t=Angels+and+Insects
# Counter value for movie White Squall (1996)86
# Downloading the image :White Squall (1996)
# Name in item is White Squall
# http://www.omdbapi.com/?t=White+Squall
# Counter value for movie Dunston Checks In (1996)87
# Downloading the image :Dunston Checks In (1996)
# Counter value for movie Black Sheep (1996)88
# Downloading the image :Black Sheep (1996)
# Name in item is Dunston Checks In
# http://www.omdbapi.com/?t=Dunston+Checks+In
# Counter value for movie Nick of Time (1995)89
# Downloading the image :Nick of Time (1995)
# Name in item is Black Sheep
# http://www.omdbapi.com/?t=Black+Sheep
# Name in item is Nick of Time
# http://www.omdbapi.com/?t=Nick+of+Time
# Counter value for movie 90
# Downloading the image :
# counter value :90
# Error with
# Counter value for movie 91
# Downloading the image :
# counter value :91
# Error with
# Counter value for movie Mary Reilly (1996)92
# Downloading the image :Mary Reilly (1996)
# Name in item is Mary Reilly
# http://www.omdbapi.com/?t=Mary+Reilly
# Counter value for movie Vampire in Brooklyn (1995)93
# Downloading the image :Vampire in Brooklyn (1995)
# Counter value for movie Beautiful Girls (1996)94
# Downloading the image :Beautiful Girls (1996)
# Name in item is Vampire in Brooklyn
# http://www.omdbapi.com/?t=Vampire+in+Brooklyn
# Counter value for movie Broken Arrow (1996)95
# Downloading the image :Broken Arrow (1996)
# Name in item is Beautiful Girls
# http://www.omdbapi.com/?t=Beautiful+Girls
# Counter value for movie In the Bleak Midwinter (1995)96
# Downloading the image :In the Bleak Midwinter (1995)
# Name in item is Broken Arrow
# http://www.omdbapi.com/?t=Broken+Arrow
# Counter value for movie Hate (Haine, La) (1995)97
# Downloading the image :Hate (Haine, La) (1995)
# Name in item is In the Bleak Midwinter (2004) (TV Episode)  - Season 14 | Episode 13  - Heartbeat
# http://www.omdbapi.com/?t=In+the+Bleak+Midwinter+(2004)+(TV+Episode)+-+Season+14+|+Episode+13+-+Heartbeat
# Name in item is La Haine
# http://www.omdbapi.com/?t=La+Haine
# Exception in thread Thread-120:
# Traceback (most recent call last):
#   File "/home/sourabhkondapaka/anaconda3/envs/py2/lib/python2.7/threading.py", line 801, in __bootstrap_inner
#     self.run()
#   File "/home/sourabhkondapaka/anaconda3/envs/py2/lib/python2.7/threading.py", line 754, in run
#     self.__target(*self.__args, **self.__kwargs)
#   File "<ipython-input-4-a7de096a7c9f>", line 54, in th
#     img = requests.get(jsontopython['Poster'])
# KeyError: 'Poster'
# Counter value for movie Shopping (1994)98
# Downloading the image :Shopping (1994)
# Counter value for movie Heidi Fleiss: Hollywood Madam (1995)99
# Downloading the image :Heidi Fleiss: Hollywood Madam (1995)
# Name in item is Shopping
# http://www.omdbapi.com/?t=Shopping
# Counter value for movie City Hall (1996)100
# Downloading the image :City Hall (1996)
# Name in item is Heidi Fleiss: Hollywood Madam
# http://www.omdbapi.com/?t=Heidi+Fleiss:+Hollywood+Madam
# Counter value for movie Bottle Rocket (1996)101
# Downloading the image :Bottle Rocket (1996)
# Name in item is City Hall
# http://www.omdbapi.com/?t=City+Hall
# Counter value for movie Mr. Wrong (1996)102
# Downloading the image :Mr. Wrong (1996)
# Name in item is Bottle Rocket
# http://www.omdbapi.com/?t=Bottle+Rocket
# Name in item is Mr. Wrong
# http://www.omdbapi.com/?t=Mr.+Wrong
# Counter value for movie Unforgettable (1996)103
# Downloading the image :Unforgettable (1996)
# Counter value for movie Happy Gilmore (1996)104
# Downloading the image :Happy Gilmore (1996)
# Name in item is Unforgettable
# http://www.omdbapi.com/?t=Unforgettable
# Counter value for movie Bridges of Madison County, The (1995)105
# Downloading the image :Bridges of Madison County, The (1995)
# Name in item is Happy Gilmore
# http://www.omdbapi.com/?t=Happy+Gilmore
# Counter value for movie 106
# Downloading the image :
# Name in item is The Bridges of Madison County
# http://www.omdbapi.com/?t=The+Bridges+of+Madison+County
# Counter value for movie Muppet Treasure Island (1996)107
# Downloading the image :Muppet Treasure Island (1996)
# counter value :107
# Error with
# Counter value for movie Catwalk (1996)108
# Downloading the image :Catwalk (1996)
# Name in item is Muppet Treasure Island
# http://www.omdbapi.com/?t=Muppet+Treasure+Island
# counter value :108
# Error with Catwalk (1996)
# Counter value for movie 109
# Downloading the image :
# Counter value for movie Braveheart (1995)110
# Downloading the image :Braveheart (1995)
# counter value :110
# Error with
# Name in item is Braveheart
# http://www.omdbapi.com/?t=Braveheart
# Counter value for movie Taxi Driver (1976)111
# Downloading the image :Taxi Driver (1976)
# Name in item is Taxi Driver
# http://www.omdbapi.com/?t=Taxi+Driver
# Counter value for movie Rumble in the Bronx (Hont faan kui) (1995)112
# Downloading the image :Rumble in the Bronx (Hont faan kui) (1995)
# Counter value for movie Before and After (1996)113
# Downloading the image :Before and After (1996)
# counter value :113
# Error with Rumble in the Bronx (Hont faan kui) (1995)
# Counter value for movie Margaret's Museum (1995)114
# Downloading the image :Margaret's Museum (1995)
# Name in item is Before and After
# http://www.omdbapi.com/?t=Before+and+After
# Counter value for movie 115
# Downloading the image :
# Name in item is Margaret's Museum
# http://www.omdbapi.com/?t=Margaret's+Museum
# Counter value for movie Anne Frank Remembered (1995)116
# Downloading the image :Anne Frank Remembered (1995)
# counter value :116
# Error with
# Name in item is Anne Frank Remembered
# http://www.omdbapi.com/?t=Anne+Frank+Remembered
# Counter value for movie Young Poisoner's Handbook, The (1995)117
# Downloading the image :Young Poisoner's Handbook, The (1995)
# Name in item is The Young Poisoner's Handbook
# http://www.omdbapi.com/?t=The+Young+Poisoner's+Handbook
# Counter value for movie If Lucy Fell (1996)118
# Downloading the image :If Lucy Fell (1996)
# Name in item is If Lucy Fell
# http://www.omdbapi.com/?t=If+Lucy+Fell
# Counter value for movie Steal Big, Steal Little (1995)119
# Downloading the image :Steal Big, Steal Little (1995)
# Name in item is Steal Big Steal Little
# http://www.omdbapi.com/?t=Steal+Big+Steal+Little
# Counter value for movie 120
# Downloading the image :
# Counter value for movie Boys of St. Vincent, The (1992)121
# Downloading the image :Boys of St. Vincent, The (1992)
# counter value :121
# Error with
# Name in item is The Boys of St. Vincent
# http://www.omdbapi.com/?t=The+Boys+of+St.+Vincent
# Counter value for movie Boomerang (1992)122
# Downloading the image :Boomerang (1992)
# Name in item is Boomerang
# http://www.omdbapi.com/?t=Boomerang
# Counter value for movie Chungking Express (Chung Hing sam lam) (1994)123
# Downloading the image :Chungking Express (Chung Hing sam lam) (1994)
# Name in item is Chungking Express
# http://www.omdbapi.com/?t=Chungking+Express
# Counter value for movie Star Maker, The (Uomo delle stelle, L') (1995)124
# Downloading the image :Star Maker, The (Uomo delle stelle, L') (1995)
# counter value :124
# Error with Star Maker, The (Uomo delle stelle, L') (1995)
# Counter value for movie Flirting With Disaster (1996)125
# Downloading the image :Flirting With Disaster (1996)
# Counter value for movie NeverEnding Story III, The (1994)126
# Downloading the image :NeverEnding Story III, The (1994)
# Name in item is Flirting with Disaster
# http://www.omdbapi.com/?t=Flirting+with+Disaster
# Counter value for movie 127
# Downloading the image :
# Name in item is The Neverending Story III
# http://www.omdbapi.com/?t=The+Neverending+Story+III
# Counter value for movie 128
# Downloading the image :
# counter value :128
# Error with
# counter value :128
# Error with
# Counter value for movie Pie in the Sky (1996)129
# Downloading the image :Pie in the Sky (1996)
# Name in item is Pie in the Sky
# http://www.omdbapi.com/?t=Pie+in+the+Sky
# Counter value for movie Angela (1995)130
# Downloading the image :Angela (1995)
# Counter value for movie Frankie Starlight (1995)131
# Downloading the image :Frankie Starlight (1995)
# Name in item is Angela
# http://www.omdbapi.com/?t=Angela
# Counter value for movie Jade (1995)132
# Downloading the image :Jade (1995)
# Name in item is Frankie Starlight
# http://www.omdbapi.com/?t=Frankie+Starlight
# Exception in thread Thread-141:
# Traceback (most recent call last):
#   File "/home/sourabhkondapaka/anaconda3/envs/py2/lib/python2.7/threading.py", line 801, in __bootstrap_inner
#     self.run()
#   File "/home/sourabhkondapaka/anaconda3/envs/py2/lib/python2.7/threading.py", line 754, in run
#     self.__target(*self.__args, **self.__kwargs)
#   File "<ipython-input-4-a7de096a7c9f>", line 52, in th
#     content = urllib2.urlopen(movie_url).read()
#   File "/home/sourabhkondapaka/anaconda3/envs/py2/lib/python2.7/urllib2.py", line 154, in urlopen
#     return opener.open(url, data, timeout)
#   File "/home/sourabhkondapaka/anaconda3/envs/py2/lib/python2.7/urllib2.py", line 435, in open
#     response = meth(req, response)
#   File "/home/sourabhkondapaka/anaconda3/envs/py2/lib/python2.7/urllib2.py", line 548, in http_response
#     'http', request, response, code, msg, hdrs)
#   File "/home/sourabhkondapaka/anaconda3/envs/py2/lib/python2.7/urllib2.py", line 473, in error
#     return self._call_chain(*args)
#   File "/home/sourabhkondapaka/anaconda3/envs/py2/lib/python2.7/urllib2.py", line 407, in _call_chain
#     result = func(*args)
#   File "/home/sourabhkondapaka/anaconda3/envs/py2/lib/python2.7/urllib2.py", line 556, in http_error_default
#     raise HTTPError(req.get_full_url(), code, msg, hdrs, fp)
# HTTPError: HTTP Error 522: Origin Connection Time-out
# Counter value for movie 133
# Downloading the image :
# Name in item is Jade
# http://www.omdbapi.com/?t=Jade
# counter value :133
# Error with
# Counter value for movie 134
# Downloading the image :
# counter value :134
# Error with
# Counter value for movie Down Periscope (1996)135
# Downloading the image :Down Periscope (1996)
# Name in item is Down Periscope
# http://www.omdbapi.com/?t=Down+Periscope
# Counter value for movie 136
# Downloading the image :
# counter value :136
# Error with
# Counter value for movie Man of the Year (1995)137
# Downloading the image :Man of the Year (1995)
# Counter value for movie 138
# Downloading the image :
# Name in item is Man of the Year
# http://www.omdbapi.com/?t=Man+of+the+Year
# counter value :138
# Error with
# Counter value for movie 139
# Downloading the image :
# counter value :139
# Error with
# Counter value for movie Up Close and Personal (1996)140
# Downloading the image :Up Close and Personal (1996)
# Counter value for movie Birdcage, The (1996)141
# Downloading the image :Birdcage, The (1996)
# Name in item is Up Close and Personal
# http://www.omdbapi.com/?t=Up+Close+and+Personal
# Exception in thread Thread-164:
# Traceback (most recent call last):
#   File "/home/sourabhkondapaka/anaconda3/envs/py2/lib/python2.7/threading.py", line 801, in __bootstrap_inner
#     self.run()
#   File "/home/sourabhkondapaka/anaconda3/envs/py2/lib/python2.7/threading.py", line 754, in run
#     self.__target(*self.__args, **self.__kwargs)
#   File "<ipython-input-4-a7de096a7c9f>", line 54, in th
#     img = requests.get(jsontopython['Poster'])
#   File "/home/sourabhkondapaka/anaconda3/envs/py2/lib/python2.7/site-packages/requests/api.py", line 70, in get
#     return request('get', url, params=params, **kwargs)
#   File "/home/sourabhkondapaka/anaconda3/envs/py2/lib/python2.7/site-packages/requests/api.py", line 56, in request
#     return session.request(method=method, url=url, **kwargs)
#   File "/home/sourabhkondapaka/anaconda3/envs/py2/lib/python2.7/site-packages/requests/sessions.py", line 474, in request
#     prep = self.prepare_request(req)
#   File "/home/sourabhkondapaka/anaconda3/envs/py2/lib/python2.7/site-packages/requests/sessions.py", line 407, in prepare_request
#     hooks=merge_hooks(request.hooks, self.hooks),
#   File "/home/sourabhkondapaka/anaconda3/envs/py2/lib/python2.7/site-packages/requests/models.py", line 302, in prepare
#     self.prepare_url(url, params)
#   File "/home/sourabhkondapaka/anaconda3/envs/py2/lib/python2.7/site-packages/requests/models.py", line 382, in prepare_url
#     raise MissingSchema(error)
# MissingSchema: Invalid URL 'N/A': No schema supplied. Perhaps you meant http://N/A?
# Name in item is The Birdcage
# http://www.omdbapi.com/?t=The+Birdcage
# Counter value for movie 142
# Downloading the image :
# Counter value for movie 143
# Downloading the image :
# counter value :143
# Error with
# counter value :143
# Error with
# Counter value for movie Brothers McMullen, The (1995)144
# Downloading the image :Brothers McMullen, The (1995)
# Counter value for movie Bad Boys (1995)145
# Downloading the image :Bad Boys (1995)
# Name in item is Something to Talk About/Unzipped/Virtuosity/A Walk in the Clouds/The Brothers McMullen/Double Happiness (1995) (TV Episode)  - Season 9 | Episode 44  - Siskel & Ebert
# http://www.omdbapi.com/?t=Something+to+Talk+About/Unzipped/Virtuosity/A+Walk+in+the+Clouds/The+Brothers+McMullen/Double+Happiness+(1995)+(TV+Episode)+-+Season+9+|+Episode+44+-+Siskel+&+Ebert
# Exception in thread Thread-168:
# Traceback (most recent call last):
#   File "/home/sourabhkondapaka/anaconda3/envs/py2/lib/python2.7/threading.py", line 801, in __bootstrap_inner
#     self.run()
#   File "/home/sourabhkondapaka/anaconda3/envs/py2/lib/python2.7/threading.py", line 754, in run
#     self.__target(*self.__args, **self.__kwargs)
#   File "<ipython-input-4-a7de096a7c9f>", line 54, in th
#     img = requests.get(jsontopython['Poster'])
# KeyError: 'Poster'
# Counter value for movie Amazing Panda Adventure, The (1995)146
# Downloading the image :Amazing Panda Adventure, The (1995)
# Name in item is Bad Boys
# http://www.omdbapi.com/?t=Bad+Boys
# Counter value for movie Basketball Diaries, The (1995)147
# Downloading the image :Basketball Diaries, The (1995)
# Name in item is The Amazing Panda Adventure
# http://www.omdbapi.com/?t=The+Amazing+Panda+Adventure
# Counter value for movie Awfully Big Adventure, An (1995)148
# Downloading the image :Awfully Big Adventure, An (1995)
# Name in item is The Basketball Diaries
# http://www.omdbapi.com/?t=The+Basketball+Diaries
# Counter value for movie Amateur (1994)149
# Downloading the image :Amateur (1994)
# Name in item is An Awfully Big Adventure
# http://www.omdbapi.com/?t=An+Awfully+Big+Adventure
# Name in item is Amateur
# http://www.omdbapi.com/?t=Amateur
# Counter value for movie Apollo 13 (1995)150
# Downloading the image :Apollo 13 (1995)
# Name in item is Apollo 13 (I)
# http://www.omdbapi.com/?t=Apollo+13+(I)
# Counter value for movie Rob Roy (1995)151
# Downloading the image :Rob Roy (1995)
# Exception in thread Thread-174:
# Traceback (most recent call last):
#   File "/home/sourabhkondapaka/anaconda3/envs/py2/lib/python2.7/threading.py", line 801, in __bootstrap_inner
#     self.run()
#   File "/home/sourabhkondapaka/anaconda3/envs/py2/lib/python2.7/threading.py", line 754, in run
#     self.__target(*self.__args, **self.__kwargs)
#   File "<ipython-input-4-a7de096a7c9f>", line 54, in th
#     img = requests.get(jsontopython['Poster'])
# KeyError: 'Poster'
# Name in item is Rob Roy
# http://www.omdbapi.com/?t=Rob+Roy
# Counter value for movie Addiction, The (1995)152
# Downloading the image :Addiction, The (1995)
# Counter value for movie Batman Forever (1995)153
# Downloading the image :Batman Forever (1995)
# Name in item is Addiction: This Is Not a Love Story
# http://www.omdbapi.com/?t=Addiction:+This+Is+Not+a+Love+Story
# Counter value for movie Beauty of the Day (Belle de jour) (1967)154
# Downloading the image :Beauty of the Day (Belle de jour) (1967)
# Exception in thread Thread-176:
# Traceback (most recent call last):
#   File "/home/sourabhkondapaka/anaconda3/envs/py2/lib/python2.7/threading.py", line 801, in __bootstrap_inner
#     self.run()
#   File "/home/sourabhkondapaka/anaconda3/envs/py2/lib/python2.7/threading.py", line 754, in run
#     self.__target(*self.__args, **self.__kwargs)
#   File "<ipython-input-4-a7de096a7c9f>", line 54, in th
#     img = requests.get(jsontopython['Poster'])
# KeyError: 'Poster'

# Traceback (most recent call last):
#   File "/home/sourabhkondapaka/anaconda3/envs/py2/lib/python2.7/threading.py", line 801, in __bootstrap_inner
#     self.run()
#   File "/home/sourabhkondapaka/anaconda3/envs/py2/lib/python2.7/threading.py", line 754, in run
#     self.__target(*self.__args, **self.__kwargs)
#   File "<ipython-input-4-a7de096a7c9f>", line 52, in th
#     content = urllib2.urlopen(movie_url).read()
#   File "/home/sourabhkondapaka/anaconda3/envs/py2/lib/python2.7/urllib2.py", line 154, in urlopen
#     return opener.open(url, data, timeout)
#   File "/home/sourabhkondapaka/anaconda3/envs/py2/lib/python2.7/urllib2.py", line 435, in open
#     response = meth(req, response)
#   File "/home/sourabhkondapaka/anaconda3/envs/py2/lib/python2.7/urllib2.py", line 548, in http_response
#     'http', request, response, code, msg, hdrs)
#   File "/home/sourabhkondapaka/anaconda3/envs/py2/lib/python2.7/urllib2.py", line 473, in error
#     return self._call_chain(*args)
#   File "/home/sourabhkondapaka/anaconda3/envs/py2/lib/python2.7/urllib2.py", line 407, in _call_chain
#     result = func(*args)
#   File "/home/sourabhkondapaka/anaconda3/envs/py2/lib/python2.7/urllib2.py", line 556, in http_error_default
#     raise HTTPError(req.get_full_url(), code, msg, hdrs, fp)
# HTTPError: HTTP Error 522: Origin Connection Time-out
#
# Exception in thread Thread-215:
# Traceback (most recent call last):
#   File "/home/sourabhkondapaka/anaconda3/envs/py2/lib/python2.7/threading.py", line 801, in __bootstrap_inner
#     self.run()
#   File "/home/sourabhkondapaka/anaconda3/envs/py2/lib/python2.7/threading.py", line 754, in run
#     self.__target(*self.__args, **self.__kwargs)
#   File "<ipython-input-4-a7de096a7c9f>", line 54, in th
#     img = requests.get(jsontopython['Poster'])
# KeyError: 'Poster'
# counter value :192
# Error with
# Counter value for movie Showgirls (1995)193
# Downloading the image :Showgirls (1995)
# Counter value for movie Smoke (1995)194
# Downloading the image :Smoke (1995)
# Name in item is Showgirls
# http://www.omdbapi.com/?t=Showgirls
# Counter value for movie Something to Talk About (1995)195
# Downloading the image :Something to Talk About (1995)
# Name in item is Smoke
# http://www.omdbapi.com/?t=Smoke
# Name in item is Something to Talk About
# http://www.omdbapi.com/?t=Something+to+Talk+About
# Counter value for movie Species (1995)196
# Downloading the image :Species (1995)
# Name in item is Species
# http://www.omdbapi.com/?t=Species
# Counter value for movie 197
# Downloading the image :
# counter value :197
# Error with
# Counter value for movie Strange Days (1995)198
# Downloading the image :Strange Days (1995)
# Counter value for movie Umbrellas of Cherbourg, The (Parapluies de Che...199
# Downloading the image :Umbrellas of Cherbourg, The (Parapluies de Che...
# Name in item is Strange Days
# http://www.omdbapi.com/?t=Strange+Days
# Counter value for movie Tie That Binds, The (1995)200
# Downloading the image :Tie That Binds, The (1995)
# counter value :200
# Error with Umbrellas of Cherbourg, The (Parapluies de Che...
# Name in item is The Tie That Binds
# http://www.omdbapi.com/?t=The+Tie+That+Binds
# Counter value for movie Three Wishes (1995)201
# Downloading the image :Three Wishes (1995)
# Counter value for movie Total Eclipse (1995)202
# Downloading the image :Total Eclipse (1995)
# Name in item is Three Wishes
# http://www.omdbapi.com/?t=Three+Wishes
# Counter value for movie To Wong Foo, Thanks for Everything! Julie Newm...203
# Downloading the image :To Wong Foo, Thanks for Everything! Julie Newm...
# Name in item is Total Eclipse
# http://www.omdbapi.com/?t=Total+Eclipse
# Counter value for movie Under Siege 2: Dark Territory (1995)204
# Downloading the image :Under Siege 2: Dark Territory (1995)
# Name in item is To Wong Foo Thanks for Everything, Julie Newmar
# http://www.omdbapi.com/?t=To+Wong+Foo+Thanks+for+Everything,+Julie+Newmar
# Name in item is Under Siege 2: Dark Territory
# http://www.omdbapi.com/?t=Under+Siege+2:+Dark+Territory
# Counter value for movie Unstrung Heroes (1995)205
# Downloading the image :Unstrung Heroes (1995)
# Counter value for movie Unzipped (1995)206
# Downloading the image :Unzipped (1995)
# Name in item is Unstrung Heroes
# http://www.omdbapi.com/?t=Unstrung+Heroes
# Name in item is Unzipped
# http://www.omdbapi.com/?t=Unzipped
# Counter value for movie Walk in the Clouds, A (1995)207
# Downloading the image :Walk in the Clouds, A (1995)
# Counter value for movie Waterworld (1995)208
# Downloading the image :Waterworld (1995)
# Name in item is A Walk in the Clouds
# http://www.omdbapi.com/?t=A+Walk+in+the+Clouds
# Name in item is Waterworld
# http://www.omdbapi.com/?t=Waterworld
# Counter value for movie White Man's Burden (1995)209
# Downloading the image :White Man's Burden (1995)
# Name in item is White Man's Burden
# http://www.omdbapi.com/?t=White+Man's+Burden
# Counter value for movie 210
# Downloading the image :
# Counter value for movie Browning Version, The (1994)211
# Downloading the image :Browning Version, The (1994)
# counter value :211
# Error with
# Name in item is The Browning Version
# http://www.omdbapi.com/?t=The+Browning+Version
# Counter value for movie 212
# Downloading the image :
# counter value :212
# Error with
# Counter value for movie Burnt by the Sun (Utomlyonnye solntsem) (1994)213
# Downloading the image :Burnt by the Sun (Utomlyonnye solntsem) (1994)
# Counter value for movie Before the Rain (Pred dozhdot) (1994)214
# Downloading the image :Before the Rain (Pred dozhdot) (1994)
# counter value :214
# Error with Burnt by the Sun (Utomlyonnye solntsem) (1994)
# Counter value for movie Before Sunrise (1995)215
# Downloading the image :Before Sunrise (1995)
# Name in item is Before the Rain
# http://www.omdbapi.com/?t=Before+the+Rain
# Counter value for movie Billy Madison (1995)216
# Downloading the image :Billy Madison (1995)
# Name in item is Before Sunrise
# http://www.omdbapi.com/?t=Before+Sunrise
# Name in item is Billy Madison
# http://www.omdbapi.com/?t=Billy+Madison
# Counter value for movie Babysitter, The (1995)217
# Downloading the image :Babysitter, The (1995)
# Counter value for movie Boys on the Side (1995)218
# Downloading the image :Boys on the Side (1995)
# Name in item is Beaver the Babysitter (1962) (TV Episode)  - Season 5 | Episode 27  - Leave It to Beaver
# http://www.omdbapi.com/?t=Beaver+the+Babysitter+(1962)+(TV+Episode)+-+Season+5+|+Episode+27+-+Leave+It+to+Beaver
# Name in item is Boys on the Side
# http://www.omdbapi.com/?t=Boys+on+the+Side
# Counter value for movie Cure, The (1995)219
# Downloading the image :Cure, The (1995)
# Exception in thread Thread-241:
# Traceback (most recent call last):
#   File "/home/sourabhkondapaka/anaconda3/envs/py2/lib/python2.7/threading.py", line 801, in __bootstrap_inner
#     self.run()
#   File "/home/sourabhkondapaka/anaconda3/envs/py2/lib/python2.7/threading.py", line 754, in run
#     self.__target(*self.__args, **self.__kwargs)
#   File "<ipython-input-4-a7de096a7c9f>", line 54, in th
#     img = requests.get(jsontopython['Poster'])
# KeyError: 'Poster'
# Name in item is The Cure
# http://www.omdbapi.com/?t=The+Cure
# Counter value for movie Castle Freak (1995)220
# Downloading the image :Castle Freak (1995)
# Name in item is Castle Freak
# http://www.omdbapi.com/?t=Castle+Freak
# Counter value for movie 221
# Downloading the image :
# counter value :221
# Error with
# Counter value for movie Circle of Friends (1995)222
# Downloading the image :Circle of Friends (1995)
# Counter value for movie Clerks (1994)223
# Downloading the image :Clerks (1994)
# Name in item is Circle of Friends
# http://www.omdbapi.com/?t=Circle+of+Friends
# Counter value for movie Don Juan DeMarco (1995)224
# Downloading the image :Don Juan DeMarco (1995)
# Name in item is Clerks
# http://www.omdbapi.com/?t=Clerks
# Name in item is Don Juan DeMarco
# http://www.omdbapi.com/?t=Don+Juan+DeMarco
# Counter value for movie Disclosure (1994)225
# Downloading the image :Disclosure (1994)
# Name in item is Disclosure
# http://www.omdbapi.com/?t=Disclosure
# Counter value for movie 226
# Downloading the image :
# counter value :226
# Error with
# Counter value for movie Drop Zone (1994)227
# Downloading the image :Drop Zone (1994)
# Name in item is Drop Zone
# http://www.omdbapi.com/?t=Drop+Zone
# Counter value for movie Destiny Turns on the Radio (1995)228
# Downloading the image :Destiny Turns on the Radio (1995)
# Counter value for movie Death and the Maiden (1994)229
# Downloading the image :Death and the Maiden (1994)
# Name in item is Destiny Turns on the Radio
# http://www.omdbapi.com/?t=Destiny+Turns+on+the+Radio
# Name in item is East of Eden
# http://www.omdbapi.com/?t=East+of+Eden
# Counter value for movie Thin Man, The (1934)950
# Downloading the image :Thin Man, The (1934)
# Name in item is The Thin Man
# http://www.omdbapi.com/?t=The+Thin+Man
# Counter value for movie His Girl Friday (1940)951
# Downloading the image :His Girl Friday (1940)
# Name in item is His Girl Friday
# http://www.omdbapi.com/?t=His+Girl+Friday
# Counter value for movie Around the World in 80 Days (1956)952
# Downloading the image :Around the World in 80 Days (1956)
# Counter value for movie It's a Wonderful Life (1946)953
# Downloading the image :It's a Wonderful Life (1946)
# Name in item is Around the World in 80 Days
# http://www.omdbapi.com/?t=Around+the+World+in+80+Days
# Counter value for movie Mr. Smith Goes to Washington (1939)954
# Downloading the image :Mr. Smith Goes to Washington (1939)
# Name in item is It's a Wonderful Life
# http://www.omdbapi.com/?t=It's+a+Wonderful+Life
# Name in item is Mr. Smith Goes to Washington
# http://www.omdbapi.com/?t=Mr.+Smith+Goes+to+Washington
# Counter value for movie Bringing Up Baby (1938)955
# Downloading the image :Bringing Up Baby (1938)
# Exception in thread Thread-963:
# Traceback (most recent call last):
#   File "/home/sourabhkondapaka/anaconda3/envs/py2/lib/python2.7/threading.py", line 801, in __bootstrap_inner
#     self.run()
#   File "/home/sourabhkondapaka/anaconda3/envs/py2/lib/python2.7/threading.py", line 754, in run
#     self.__target(*self.__args, **self.__kwargs)
#   File "<ipython-input-4-a7de096a7c9f>", line 52, in th
#     content = urllib2.urlopen(movie_url).read()
#   File "/home/sourabhkondapaka/anaconda3/envs/py2/lib/python2.7/urllib2.py", line 154, in urlopen
#     return opener.open(url, data, timeout)
#   File "/home/sourabhkondapaka/anaconda3/envs/py2/lib/python2.7/urllib2.py", line 435, in open
#     response = meth(req, response)
#   File "/home/sourabhkondapaka/anaconda3/envs/py2/lib/python2.7/urllib2.py", line 548, in http_response
#     'http', request, response, code, msg, hdrs)
#   File "/home/sourabhkondapaka/anaconda3/envs/py2/lib/python2.7/urllib2.py", line 473, in error
#     return self._call_chain(*args)
#   File "/home/sourabhkondapaka/anaconda3/envs/py2/lib/python2.7/urllib2.py", line 407, in _call_chain
#     result = func(*args)
#   File "/home/sourabhkondapaka/anaconda3/envs/py2/lib/python2.7/urllib2.py", line 556, in http_error_default
#     raise HTTPError(req.get_full_url(), code, msg, hdrs, fp)
# HTTPError: HTTP Error 522: Origin Connection Time-out
# Counter value for movie Penny Serenade (1941)956
# Downloading the image :Penny Serenade (1941)
# Name in item is Bringing Up Baby
# http://www.omdbapi.com/?t=Bringing+Up+Baby
# Name in item is Penny Serenade
# http://www.omdbapi.com/?t=Penny+Serenade
# Counter value for movie Scarlet Letter, The (1926)957
# Downloading the image :Scarlet Letter, The (1926)
# Name in item is The Scarlet Letter - Thug Notes Summary and Analysis (2013) (TV Episode)  - Season 1 | Episode 20  - Thug Notes
# http://www.omdbapi.com/?t=The+Scarlet+Letter+-+Thug+Notes+Summary+and+Analysis+(2013)+(TV+Episode)+-+Season+1+|+Episode+20+-+Thug+Notes
# Counter value for movie 958
# Downloading the image :
# Exception in thread Thread-981:
# Traceback (most recent call last):
#   File "/home/sourabhkondapaka/anaconda3/envs/py2/lib/python2.7/threading.py", line 801, in __bootstrap_inner
#     self.run()
#   File "/home/sourabhkondapaka/anaconda3/envs/py2/lib/python2.7/threading.py", line 754, in run
#     self.__target(*self.__args, **self.__kwargs)
#   File "<ipython-input-4-a7de096a7c9f>", line 54, in th
#     img = requests.get(jsontopython['Poster'])
# KeyError: 'Poster'
# counter value :958
# Error with
# Counter value for movie 959
# Downloading the image :
# counter value :959
# Error with
# Counter value for movie Angel on My Shoulder (1946)960
# Downloading the image :Angel on My Shoulder (1946)
# Name in item is Angel on My Shoulder
# http://www.omdbapi.com/?t=Angel+on+My+Shoulder
# Counter value for movie Little Lord Fauntleroy (1936)961
# Downloading the image :Little Lord Fauntleroy (1936)
# Name in item is Little Lord Fauntleroy
# http://www.omdbapi.com/?t=Little+Lord+Fauntleroy
# Counter value for movie They Made Me a Criminal (1939)962
# Downloading the image :They Made Me a Criminal (1939)
# Name in item is They Made Me a Criminal
# http://www.omdbapi.com/?t=They+Made+Me+a+Criminal
# Counter value for movie Inspector General, The (1949)963
# Downloading the image :Inspector General, The (1949)
# Name in item is The Inspector General
# http://www.omdbapi.com/?t=The+Inspector+General
# Counter value for movie Angel and the Badman (1947)964
# Downloading the image :Angel and the Badman (1947)
# Counter value for movie 39 Steps, The (1935)965
# Downloading the image :39 Steps, The (1935)
# Name in item is Angel and the Badman
# http://www.omdbapi.com/?t=Angel+and+the+Badman
# Name in item is The 39 Steps
# http://www.omdbapi.com/?t=The+39+Steps
# Counter value for movie A Walk in the Sun (1945)966
# Downloading the image :A Walk in the Sun (1945)
# Counter value for movie 967
# Downloading the image :
# Name in item is A Walk in the Sun
# http://www.omdbapi.com/?t=A+Walk+in+the+Sun
# Counter value for movie Night of the Living Dead (1968)968
# Downloading the image :Night of the Living Dead (1968)
# counter value :968
# Error with
# Counter value for movie African Queen, The (1951)969
# Downloading the image :African Queen, The (1951)
# Name in item is Night of the Living Dead
# http://www.omdbapi.com/?t=Night+of+the+Living+Dead
# Counter value for movie Beat the Devil (1953)970
# Downloading the image :Beat the Devil (1953)
# Name in item is The African Queen (1951) (2017) (TV Episode)  - Season 1 | Episode 1  - Vermont Film Essentials
# http://www.omdbapi.com/?t=The+African+Queen+(1951)+(2017)+(TV+Episode)+-+Season+1+|+Episode+1+-+Vermont+Film+Essentials
# Exception in thread Thread-993:
# Traceback (most recent call last):
#   File "/home/sourabhkondapaka/anaconda3/envs/py2/lib/python2.7/threading.py", line 801, in __bootstrap_inner
#     self.run()
#   File "/home/sourabhkondapaka/anaconda3/envs/py2/lib/python2.7/threading.py", line 754, in run
#     self.__target(*self.__args, **self.__kwargs)
#   File "<ipython-input-4-a7de096a7c9f>", line 54, in th
#     img = requests.get(jsontopython['Poster'])
# KeyError: 'Poster'
# Counter value for movie Cat on a Hot Tin Roof (1958)971
# Downloading the image :Cat on a Hot Tin Roof (1958)
# Name in item is Beat the Devil
# http://www.omdbapi.com/?t=Beat+the+Devil
# Counter value for movie Last Time I Saw Paris, The (1954)972
# Downloading the image :Last Time I Saw Paris, The (1954)
# Name in item is Cat on a Hot Tin Roof
# http://www.omdbapi.com/?t=Cat+on+a+Hot+Tin+Roof
# Name in item is The Last Time I Saw Paris
# http://www.omdbapi.com/?t=The+Last+Time+I+Saw+Paris
# Counter value for movie Meet John Doe (1941)973
# Downloading the image :Meet John Doe (1941)
# Counter value for movie 974
# Downloading the image :
# Name in item is Meet John Doe
# http://www.omdbapi.com/?t=Meet+John+Doe
# counter value :974
# Error with
# Counter value for movie 975
# Downloading the image :
# counter value :975
# Error with
# Counter value for movie Farewell to Arms, A (1932)976
# Downloading the image :Farewell to Arms, A (1932)
# Name in item is A Farewell to Arms
# http://www.omdbapi.com/?t=A+Farewell+to+Arms
# Counter value for movie 977
# Downloading the image :
# counter value :977
# Error with
# Counter value for movie 978
# Downloading the image :
# counter value :978
# Error with
# Counter value for movie 979
# Downloading the image :
# counter value :979
# Error with
# Counter value for movie Yes, Madam (a.k.a. Police Assassins) (a.k.a. I...980
# Downloading the image :Yes, Madam (a.k.a. Police Assassins) (a.k.a. I...
# counter value :980
# Error with Yes, Madam (a.k.a. Police Assassins) (a.k.a. I...
# Counter value for movie Dangerous Ground (1997)981
# Downloading the image :Dangerous Ground (1997)
# Counter value for movie Picnic (1955)982
# Downloading the image :Picnic (1955)
# Name in item is Dangerous Ground
# http://www.omdbapi.com/?t=Dangerous+Ground
# Name in item is Picnic
# http://www.omdbapi.com/?t=Picnic
# Counter value for movie 983
# Downloading the image :
# Counter value for movie Pompatus of Love, The (1996)984
# Downloading the image :Pompatus of Love, The (1996)
# counter value :984
# Error with
# Name in item is Jack/Aladdin and the King of Thieves/Escape from L.A./Basquiat/The Pompatus of Love (1996) (TV Episode)  - Season 10 | Episode 48  - Siskel & Ebert
# http://www.omdbapi.com/?t=Jack/Aladdin+and+the+King+of+Thieves/Escape+from+L.A./Basquiat/The+Pompatus+of+Love+(1996)+(TV+Episode)+-+Season+10+|+Episode+48+-+Siskel+&+Ebert
# Counter value for movie 985
# Downloading the image :
# Exception in thread Thread-1008:
# Traceback (most recent call last):
#   File "/home/sourabhkondapaka/anaconda3/envs/py2/lib/python2.7/threading.py", line 801, in __bootstrap_inner
#     self.run()
#   File "/home/sourabhkondapaka/anaconda3/envs/py2/lib/python2.7/threading.py", line 754, in run
#     self.__target(*self.__args, **self.__kwargs)
#   File "<ipython-input-4-a7de096a7c9f>", line 54, in th
#     img = requests.get(jsontopython['Poster'])
# KeyError: 'Poster'
# counter value :985
# Error with
# Counter value for movie Fly Away Home (1996)986
# Downloading the image :Fly Away Home (1996)
# Name in item is Fly Away Home
# http://www.omdbapi.com/?t=Fly+Away+Home
# Counter value for movie Bliss (1997)987
# Downloading the image :Bliss (1997)
# Counter value for movie Grace of My Heart (1996)988
# Downloading the image :Grace of My Heart (1996)
# Name in item is Bliss
# http://www.omdbapi.com/?t=Bliss
# Name in item is Grace of My Heart
# http://www.omdbapi.com/?t=Grace+of+My+Heart
# Counter value for movie 989
# Downloading the image :
# Counter value for movie Maximum Risk (1996)990
# Downloading the image :Maximum Risk (1996)
# counter value :990
# Error with
# Counter value for movie Michael Collins (1996)991
# Downloading the image :Michael Collins (1996)
# Name in item is Maximum Risk
# http://www.omdbapi.com/?t=Maximum+Risk
# Counter value for movie Rich Man's Wife, The (1996)992
# Downloading the image :Rich Man's Wife, The (1996)
# Name in item is Michael Collins
# http://www.omdbapi.com/?t=Michael+Collins
# Counter value for movie 993
# Downloading the image :
# Name in item is The Rich Man's Wife
# http://www.omdbapi.com/?t=The+Rich+Man's+Wife
# counter value :993
# Error with
# Counter value for movie Big Night (1996)994
# Downloading the image :Big Night (1996)
# Name in item is Big Night
# http://www.omdbapi.com/?t=Big+Night
# Counter value for movie 995
# Downloading the image :
# Counter value for movie Last Man Standing (1996)996
# Downloading the image :Last Man Standing (1996)
# counter value :996
# Error with
# Counter value for movie Caught (1996)997
# Downloading the image :Caught (1996)
# Name in item is Last Man Standing
# http://www.omdbapi.com/?t=Last+Man+Standing
# Counter value for movie Set It Off (1996)998
# Downloading the image :Set It Off (1996)
# Name in item is Caught
# http://www.omdbapi.com/?t=Caught
# Name in item is Set It Off
# http://www.omdbapi.com/?t=Set+It+Off
# Counter value for movie 2 Days in the Valley (1996)999
# Downloading the image :2 Days in the Valley (1996)
# Name in item is 2 Days in the Valley
# http://www.omdbapi.com/?t=2+Days+in+the+Valley
# THreadList is
#
#
# [<Thread(Thread-24, stopped 140109259302656)>, <Thread(Thread-25, stopped 140109259302656)>, <Thread(Thread-26, stopped 140109267695360)>, <Thread(Thread-27, stopped 140109259302656)>, <Thread(Thread-28, stopped 140109259302656)>, <Thread(Thread-29, stopped 140109267695360)>, <Thread(Thread-30, stopped 140109259302656)>, <Thread(Thread-31, stopped 140109267695360)>, <Thread(Thread-32, stopped 140109259302656)>, <Thread(Thread-33, stopped 140109267695360)>, <Thread(Thread-34, stopped 140109259302656)>, <Thread(Thread-35, stopped 140109267695360)>, <Thread(Thread-36, stopped 140109278324480)>, <Thread(Thread-37, stopped 140109278324480)>, <Thread(Thread-38, stopped 140109267695360)>, <Thread(Thread-39, stopped 140109278324480)>, <Thread(Thread-40, stopped 140109267695360)>, <Thread(Thread-41, stopped 140109278324480)>, <Thread(Thread-42, stopped 140109267695360)>, <Thread(Thread-43, stopped 140109278324480)>, <Thread(Thread-44, stopped 140109259302656)>, <Thread(Thread-45, stopped 140109267695360)>, <Thread(Thread-46, stopped 140109259302656)>, <Thread(Thread-47, stopped 140109267695360)>, <Thread(Thread-48, stopped 140109259302656)>, <Thread(Thread-49, stopped 140109267695360)>, <Thread(Thread-50, stopped 140109259302656)>, <Thread(Thread-51, stopped 140109267695360)>, <Thread(Thread-52, stopped 140109259302656)>, <Thread(Thread-53, stopped 140109267695360)>, <Thread(Thread-54, stopped 140109267695360)>, <Thread(Thread-55, stopped 140109267695360)>, <Thread(Thread-56, stopped 140109259302656)>, <Thread(Thread-57, stopped 140109259302656)>, <Thread(Thread-58, stopped 140109267695360)>, <Thread(Thread-59, stopped 140109259302656)>, <Thread(Thread-60, stopped 140109267695360)>, <Thread(Thread-61, stopped 140109259302656)>, <Thread(Thread-62, stopped 140109267695360)>, <Thread(Thread-63, stopped 140109259302656)>, <Thread(Thread-64, stopped 140109267695360)>, <Thread(Thread-65, stopped 140109259302656)>, <Thread(Thread-66, stopped 140109278324480)>, <Thread(Thread-67, stopped 140109267695360)>, <Thread(Thread-68, stopped 140109259302656)>, <Thread(Thread-69, stopped 140109278324480)>, <Thread(Thread-70, stopped 140109259302656)>, <Thread(Thread-71, stopped 140109267695360)>, <Thread(Thread-72, stopped 140109259302656)>, <Thread(Thread-73, stopped 140109267695360)>, <Thread(Thread-74, stopped 140109259302656)>, <Thread(Thread-75, stopped 140109267695360)>, <Thread(Thread-76, stopped 140109259302656)>, <Thread(Thread-77, stopped 140109267695360)>, <Thread(Thread-78, stopped 140109259302656)>, <Thread(Thread-79, stopped 140109267695360)>, <Thread(Thread-80, stopped 140109259302656)>, <Thread(Thread-81, stopped 140109259302656)>, <Thread(Thread-82, stopped 140109267695360)>, <Thread(Thread-83, stopped 140109259302656)>, <Thread(Thread-84, stopped 140109267695360)>, <Thread(Thread-85, stopped 140109259302656)>, <Thread(Thread-86, stopped 140109267695360)>, <Thread(Thread-87, stopped 140109259302656)>, <Thread(Thread-88, stopped 140109267695360)>, <Thread(Thread-89, stopped 140109259302656)>, <Thread(Thread-90, stopped 140109278324480)>, <Thread(Thread-91, stopped 140109250647808)>, <Thread(Thread-92, stopped 140109278324480)>, <Thread(Thread-93, stopped 140109250647808)>, <Thread(Thread-94, stopped 140109278324480)>, <Thread(Thread-95, stopped 140109250647808)>, <Thread(Thread-96, stopped 140109278324480)>, <Thread(Thread-97, stopped 140109250647808)>, <Thread(Thread-98, stopped 140109278324480)>, <Thread(Thread-99, stopped 140109250647808)>, <Thread(Thread-100, stopped 140109278324480)>, <Thread(Thread-101, stopped 140109250647808)>, <Thread(Thread-102, stopped 140109278324480)>, <Thread(Thread-103, stopped 140109250647808)>, <Thread(Thread-104, stopped 140109278324480)>, <Thread(Thread-105, stopped 140109250647808)>, <Thread(Thread-106, stopped 140109267695360)>, <Thread(Thread-107, stopped 140109250647808)>, <Thread(Thread-108, stopped 140109267695360)>, <Thread(Thread-109, stopped 140109250647808)>, <Thread(Thread-110, stopped 14010 ...

# %%
len(missing_movies)
# Out:
# 225

# %%
new_missing_movies = filter(None, missing_movies)

# %%
len(new_missing_movies)
# Out:
# 32

# %%
for miss in new_missing_movies:
    bb = str(movies.ix[movies['movie_id'] == counter ]['title']).split()    
    q = bb.index('Name:')
    bb = ' '.join(bb[1:q])  
    print("Downloading the image :" + bb)
    item = ia.search_movie(bb)[0]
    print("Name in item is " + str(item))
    name = str(item)        
    ll = name.split()
    #ll = '+'.join(ll)
    movie_url = url + '+'.join(ll)
    print movie_url
    content = urllib2.urlopen(movie_url).read()
    jsontopython = json.loads(content)
    img = requests.get(jsontopython['Poster'])
    imgfile = open(file_path2+"/"+bb,'wb')
    for chunk in img.iter_content(100000):
        imgfile.write(chunk)
    imgfile.close()
# Out:
# Downloading the image :
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-15-328aaeff3591> in <module>()
#       4     bb = ' '.join(bb[1:q])
#       5     print("Downloading the image :" + bb)
# ----> 6     item = ia.search_movie(bb)[0]
#       7     print("Name in item is " + str(item))
#       8     name = str(item)
#
# IndexError: list index out of range

# %%
for movie in new_missing_movies:
    print movie
# Out:
# City of Lost Children, The (Cité des enfants p...
# Shanghai Triad (Yao a yao yao dao waipo qiao) ...
# Twelve Monkeys (a.k.a. 12 Monkeys) (1995)
# Seven (a.k.a. Se7en) (1995)
# Misérables, Les (1995)
# Catwalk (1996)
# Rumble in the Bronx (Hont faan kui) (1995)
# Star Maker, The (Uomo delle stelle, L') (1995)
# Umbrellas of Cherbourg, The (Parapluies de Che...
# Burnt by the Sun (Utomlyonnye solntsem) (1994)
# Enfer, L' (1994)
# Like Water for Chocolate (Como agua para choco...
# Red Firecracker, Green Firecracker (Pao Da Shu...
# To Live (Huozhe) (1994)
# Tales from the Crypt Presents: Demon Knight (1...
# Backbeat (1993)
# Wes Craven's New Nightmare (Nightmare on Elm S...
# Highlander III: The Sorcerer (a.k.a. Highlande...
# Wedding Gift, The (1994)
# Métisse (Café au Lait) (1993)
# Bread and Chocolate (Pane e cioccolata) (1973)
# Bloodsport 2 (a.k.a. Bloodsport II: The Next K...
# Alphaville (Alphaville, une étrange aventure d...
# Ghost in the Shell (Kôkaku kidôtai) (1995)
# Independence Day (a.k.a. ID4) (1996)
# My Life and Times With Antonin Artaud (En comp...
# Death in the Garden (Mort en ce jardin, La) (1...
# Eyes Without a Face (Yeux sans visage, Les) (1...
# Tales from the Crypt Presents: Bordello of Blo...
# Day the Sun Turned Cold, The (Tianguo niezi) (...
# Sunset Blvd. (a.k.a. Sunset Boulevard) (1950)
# Yes, Madam (a.k.a. Police Assassins) (a.k.a. I...
